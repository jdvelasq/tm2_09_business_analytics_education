# %%
from techminer2.tools import coverage  #  type: ignore

coverage(
    field="descriptors",
    #
    # DATABASE PARAMS:
    root_dir="../",
    database="main",
    year_filter=(2014, None),
    cited_by_filter=(None, None),
    document_type=[
        "Article",
        "Book chapter",
        "Conference paper",
        "Review",
    ],
).tail(20)
# Out:
# --INFO-- Number of documents : 96
# --INFO--   Documents with NA : 0
# --INFO--  Efective documents : 96
#     min_occ  cum_sum_documents  coverage  cum num items
# 0        79                 79   82.29 %              1
# 1        34                 82   85.42 %              2
# 2        29                 84   87.50 %              3
# 3        25                 84   87.50 %              4
# 4        17                 84   87.50 %              5
# 5        16                 84   87.50 %              6
# 6        15                 87   90.62 %              9
# 7        14                 89   92.71 %             11
# 8        13                 93   96.88 %             12
# 9        12                 93   96.88 %             13
# 10       11                 93   96.88 %             14
# 11        9                 93   96.88 %             16
# 12        8                 93   96.88 %             19
# 13        7                 93   96.88 %             23
# ...
