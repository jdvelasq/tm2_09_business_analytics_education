# %%
from techminer2.metrics import general_metrics_frame  #  type: ignore

general_metrics_frame(
    #
    # DATABASE PARAMS:
    root_dir="../",
    database="main",
    year_filter=(None, None),
    cited_by_filter=(None, None),
    document_type=[
        "Article",
        "Book chapter",
        "Conference paper",
        "Review",
    ],
)
# Out:
#                                                             Value
# Category       Item
# GENERAL        Timespan                                 2012:2024
#                Documents                                      103
#                Annual growth rate %                         35.42
#                Document average age                          5.23
#                References                                    <NA>
#                Average citations per document                9.84
#                Average citations per document per year       0.76
#                Average references per document               <NA>
#                Sources                                         62
#                Average documents per source                  1.66
# DOCUMENT TYPES Article                                         57
#                Book chapter                                     2
#                Conference paper                                43
# ...
